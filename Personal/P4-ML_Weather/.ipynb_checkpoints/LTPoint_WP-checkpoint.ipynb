# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from IPython.display import display
#Location: Latitude 50.0742 Longitude 20.9229

# %%
raw_df = pd.read_csv("LTPoint_data.txt")
raw_df
# Out:
#        year  day_of_year  wind_speed  max_wind_speed  temp_at2m  \
# 0      1982            1        2.02            2.58       1.01
# 1      1982            2        2.34            3.37      -1.63
# 2      1982            3        3.10            5.54      -0.77
# 3      1982            4        4.30            5.69       1.38
# 4      1982            5        5.14            6.38       1.98
# ...     ...          ...         ...             ...        ...
# 13960  2020           82        4.70            5.93      -2.67
# 13961  2020           83        4.77            6.77      -2.25
# 13962  2020           84        3.90            5.97      -2.20
# 13963  2020           85        4.02            6.20      -0.64
# 13964  2020           86        3.35            4.99       2.77
#
#        min_temp_at2m  tot_precipitation  surface_pressure
# 0               0.06               0.59             97.35
# 1              -4.60               0.21             98.25
# 2              -4.55               2.44             98.42
# 3               1.06               4.02             97.63
# 4               0.92               4.38             97.34
# ...              ...                ...               ...
# 13960          -5.94               2.00             99.71
# 13961          -5.81               0.20            100.25
# 13962          -6.37               0.00            100.40
# 13963          -5.50               0.03            100.16
# 13964          -3.37               0.00             99.70
#
# [13965 rows x 8 columns]

# %%
weather_data_raw = raw_df[["temp_at2m", "min_temp_at2m", "surface_pressure","wind_speed","max_wind_speed"]].copy()
weather_data_names = list(weather_data_raw.columns)

# %%
weather_data = weather_data_raw.to_numpy()
print(weather_data)
# Out:
# [[ 1.0100e+00  6.0000e-02  9.7350e+01  2.0200e+00  2.5800e+00]
#  [-1.6300e+00 -4.6000e+00  9.8250e+01  2.3400e+00  3.3700e+00]
#  [-7.7000e-01 -4.5500e+00  9.8420e+01  3.1000e+00  5.5400e+00]
#  ...
#  [-2.2000e+00 -6.3700e+00  1.0040e+02  3.9000e+00  5.9700e+00]
#  [-6.4000e-01 -5.5000e+00  1.0016e+02  4.0200e+00  6.2000e+00]
#  [ 2.7700e+00 -3.3700e+00  9.9700e+01  3.3500e+00  4.9900e+00]]

# %%
target_data_raw = raw_df["tot_precipitation"].to_list()
target_data_names = ["Znikome opady lub brak opadów","Lekkie opady","Intensywne opady"]

# %%
target_data = []
for precipitation in target_data_raw:
    if precipitation < 5:
        target_data.append(0)
    elif precipitation >= 5 and precipitation < 12:
        target_data.append(1)
    else:
        target_data.append(2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(weather_data, target_data, random_state = 0)

# %%
training_df = pd.DataFrame(X_train, columns = weather_data_names)
pd.plotting.scatter_matrix(training_df, c=y_train)
# Out:
# c:\python38-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# c:\python38-32\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1BF79598>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1CFBDFA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1CFD9FA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1CFFA9A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D01A3A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1D02E5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D02ED90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D0507C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D085B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D0A5550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1D0B9F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D0D9928>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D0FA328>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D10DD00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D12D700>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1D14D100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D162AF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D1814F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D196EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D1B68C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1D1D62C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D1E9CA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D20A6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D22A0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1D23DA90>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=9)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='uniform')

# %%
print("Test score:", knn.score(X_test,y_test))
# Out:
# Test score: 0.884020618556701

# %%
X_new = np.array([[12, -2, 102.4, 9, 15]])#temp,min_temp,surf_press,wind_speed,max_wind_speed
prediction = knn.predict(X_new)
print("Prognoza:", target_data_names[prediction[0]])
# Out:
# Prognoza: Znikome opady lub brak opadów
